# %% [markdown]
# <a href="https://colab.research.google.com/github/SiddhiTyagi/Anudip-Assignments-Projects/blob/main/PracticeSELF1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # LEVEL 1: EASY

# %%
"""Write a program to check whether a number is positive, negative, or zero."""

try:
  num=float(input("Enter number: ")) # what if this input statement is outside(above) try block?
  if num>0:
    print(f"{num:.2f} is a positive number.")
  elif num<0:
    print(f"{num:.2f} is a negative number.")
  else:
    print("0 is equal to zero.") # I WANT 0 AS 0, NOT AS 0.0

except ValueError:
  print("INVALID INPUT")
# Out:
# Enter number: 0
# 0 is equal to zero.

# %%
"""Ask the user to enter 5 numbers and print:
Sum
Average"""

number_of_nums=5
num=[0]*number_of_nums
total=0

for i in range(number_of_nums):
  num[i]=float(input(f"Enter number {i+1}: "))
  total=total+num[i]

average=total/number_of_nums

# print using only 1 print statement
print(f"Sum: {total:.2f}\nAverage: {average:.2f}")
# Out:
# Enter number 1: 10
# Enter number 2: 10
# Enter number 3: 10
# Enter number 4: 10
# Enter number 5: 10
# Sum: 50.00
# Average: 10.00

# %%
"""--------------------Print all numbers between 1 and 100 that are divisible by both 3 and 5."""

print("All numbers between 1 and 100 that are divisible by both 3 and 5 are ",end="")

divisible_num=[]

for i in range(1,101):
  if i%3==0 and i%5==0:
    divisible_num.append(i)

for i in range(len(divisible_num)):
  if i==len(divisible_num)-1:
    print(divisible_num[i])
  else:
    print(divisible_num[i],end=", ")
# Out:
# All numbers between 1 and 100 that are divisible by both 3 and 5 are 15, 30, 45, 60, 75, 90

# %%
"""---------------------Reverse a string without using slicing ([::-1]).
Example:
Input: Python
Output: nohtyP
"""

string=input("Enter a string: ")
reversed_string=""

for char in string:
  reversed_string=char+reversed_string

print(reversed_string)
# Out:
# Enter a string: sid
# dis

# %%
 """Count how many vowels are present in a string."""

string=input("Enter string: ").strip()
count=0

for char in string:
  # any other shorter way than this if?
  if char=='a' or char=='e' or char=='i' or char=='o' or char=='u' or char=='A' or char=='E' or char=='I' or char=='O' or char=='U':
    count+=1

print(f"{string} has {count} vowels.")
# Out:
# Enter string: siddhi
# siddhi has 2 vowels.

# %% [markdown]
# # LEVEL 1: EASY (STRING)

# %%
"""Ask the user to enter a string and print:
Length of the string
String in uppercase
String in lowercase"""

string=input("Enter string: ")
print(f"String: {string}")
print("Length of string:",len(string))
print(f"{string} in uppercase:",string.upper())
print(f"{string} in lowercase:",string.lower())
# Out:
# Enter string: danMEEBGFCYH
# String: danMEEBGFCYH
# Length of string: 12
# danMEEBGFCYH in uppercase: DANMEEBGFCYH
# danMEEBGFCYH in lowercase: danmeebgfcyh

# %%
"""Check whether a string is empty.
Example:
Input: ""

Output: String is empty."""

string=input("Enter string: ")

if len(string)==0:
  print("String is empty.")
else:
  print("String is NOT empty.")
# Out:
# Enter string: gi
# String is NOT empty.

# %%
"""Count the total number of characters in a string without using len()."""

string=input("Enter string: ")
count=0

for char in string:
  count+=1

print(f"Total number of characters in {string} is",count)
# Out:
# Enter string: sid
# Total number of characters in sid is 3

# %%
"""Print every character of a string on a new line.
Example:
Input: Python

Output:
P
y
t
h
o
n
"""

string=input("Enter string: ")

for char in string:
  print(char)
# Out:
# Enter string: python
# p
# y
# t
# h
# o
# n

# %%
"""Count the number of vowels"""

string=input("Enter string: ")
count=0

for char in string:
  if char.lower() in "aeiou":
    count+=1

print(count)
# Out:
# Enter string: SIDDhi
# 2

# %%
"""Count:
Uppercase letters
Lowercase letters
Digits
Spaces
Example: Hello 123
Output: """

string=input("Enter string: ")
uppercase_count=0
lowercase_count=0
digit_count=0
space_count=0

for char in string:
  if char in "ABCDEFGHIJKLMNOPQRSTUVWXYZ":
    uppercase_count+=1
  elif char in "abcdefghijklmnopqrstuvwxyz":
    lowercase_count+=1
  elif char in "0123456789":
    pass
  else:
    space_count+=1

print(f"String: {string}")
print(f"Uppercase letters: {uppercase_count}")
print(f"Lowercase letters: {lowercase_coun}")
print(f"Digits: {digit_count}")
print(f"Spaces: {space_count}")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_3185/763553379.py in <cell line: 0>()
#       7 Output: """
#       8
# ----> 9 string=input("Enter string: ")
#      10 uppercase_count=0
#      11 lowercase_count=0
#
# TypeError: 'str' object is not callable

# %%
string="abcdefghijklmnopqrstuvwxyz"
print((input).upper())
# Out:
# ABCDEFGHIJKLMNOPQRSTUVWXYZ

# %% [markdown]
# # LEVEL 2: MEDIUM

# %%
"""Check whether a string is a palindrome.
Example: madam
Output: Palindrome"""
