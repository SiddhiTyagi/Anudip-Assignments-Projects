# %% [markdown]
# <a href="https://colab.research.google.com/github/SiddhiTyagi/Anudip-Assignments-Projects/blob/main/Project1_BankAccountSystem.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
"""Make a logging in function where the user enters their name, phone number, pan card, gets an otp AND then his account details are fetched"""

print(
    "WELCOME TO HDFC BANK!".center(150),
    "ENJOY OUR ONLINE BANK ACCOUNT SERVICES!".center(148),
    sep="\n"
)

print("CHOOSE THE SERVICE: ")
print("1. Open Account\n2. Deposit\n3. Withdraw\n4. Transfer\n5. Balance\n6. Mini Statement\n7. Customer Details\n8. Bank Report\n9. Exit")

try:
  choice=int(input("\nEnter choice: "))

  match choice:
    case 1:
      print("\n"+"ACCOUNT DETAILS".center(145))
      # call the fetched details function and print it
    case 2:
      pass
    case 3:
      pass
    case 4:
      pass
    case 5:
      pass
    case 6:
      pass
    case 7:
      pass
    case 8:
      pass
    case 9:
      pass
    case _:
      print("INVALID CHOICE!")

except ValueError:
  print(
      "\n"+"INVALID CHOICE!".center(150),
      "TRY AGAIN".center(150),
      sep="\n"
      )
